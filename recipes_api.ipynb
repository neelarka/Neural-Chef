# %%
import requests

# %%
def getRecipeByCuisine(cuisine,ingredients,type_):
    base_url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/searchComplex?"
        
    params = {
        "limitLicense":"false",
        "offset":"0",
        "number":"3",
        "cuisine": cuisine,
        "includeIngredients": ingredients,    
        "type": type_,
        "instructionsRequired":"true",
        "addRecipeInformation":"true",       
            }
    headers={
            "X-RapidAPI-Key": "V6MthOQa2Umshc2XxrGVtYJLWTTgp1ltq2HjsnImE1bGSKU3pK"
            }
    response = requests.get(base_url,headers = headers,params=params)
    return response

# %%
ingredients = ["broccoli","onion","peppers"]
r = getRecipeByCuisine("thai",ingredients,"main course")
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'results': [{'vegetarian': False,
#    'vegan': False,
#    'glutenFree': True,
#    'dairyFree': True,
#    'veryHealthy': False,
#    'cheap': False,
#    'veryPopular': False,
#    'sustainable': False,
#    'weightWatcherSmartPoints': 13,
#    'gaps': 'no',
#    'lowFodmap': False,
#    'ketogenic': False,
#    'whole30': False,
#    'sourceUrl': 'http://www.dinner-mom.com/thai-beef-shaved-broccoli-stalk-ribbons/',
#    'spoonacularSourceUrl': 'https://spoonacular.com/thai-beef-and-shaved-broccoli-stalk-ribbons-611942',
#    'aggregateLikes': 73,
#    'spoonacularScore': 86.0,
#    'healthScore': 24.0,
#    'creditText': 'Dinner Mom',
#    'sourceName': 'Dinner Mom',
#    'pricePerServing': 216.49,
#    'id': 611942,
#    'title': 'Thai Beef and Shaved Broccoli Stalk Ribbons',
#    'readyInMinutes': 45,
#    'servings': 4,
#    'image': 'https://spoonacular.com/recipeImages/611942-312x231.jpg',
#    'imageType': 'jpg',
#    'cuisines': ['asian', 'thai'],
# ...

# %%
base_url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/searchComplex?"
params = {
    "limitLicense":"false",
    "offset":"0",
    "number":"3",
    "cuisine":"thai",
    "includeIngredients":["broccoli","onion","peppers"],    
    "type":"main course",
    "instructionsRequired":"true",
    "addRecipeInformation":"true",       
        }
headers={
        "X-RapidAPI-Key": "V6MthOQa2Umshc2XxrGVtYJLWTTgp1ltq2HjsnImE1bGSKU3pK"
        }

# %%
response = requests.get(base_url,headers = headers,params=params)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'results': [{'vegetarian': False,
#    'vegan': False,
#    'glutenFree': True,
#    'dairyFree': True,
#    'veryHealthy': False,
#    'cheap': False,
#    'veryPopular': False,
#    'sustainable': False,
#    'weightWatcherSmartPoints': 13,
#    'gaps': 'no',
#    'lowFodmap': False,
#    'ketogenic': False,
#    'whole30': False,
#    'sourceUrl': 'http://www.dinner-mom.com/thai-beef-shaved-broccoli-stalk-ribbons/',
#    'spoonacularSourceUrl': 'https://spoonacular.com/thai-beef-and-shaved-broccoli-stalk-ribbons-611942',
#    'aggregateLikes': 73,
#    'spoonacularScore': 86.0,
#    'healthScore': 24.0,
#    'creditText': 'Dinner Mom',
#    'sourceName': 'Dinner Mom',
#    'pricePerServing': 216.49,
#    'id': 611942,
#    'title': 'Thai Beef and Shaved Broccoli Stalk Ribbons',
#    'readyInMinutes': 45,
#    'servings': 4,
#    'image': 'https://spoonacular.com/recipeImages/611942-312x231.jpg',
#    'imageType': 'jpg',
#    'cuisines': ['asian', 'thai'],
# ...

# %%
response_data = response.json()['results'][0]
print(response_data['sourceUrl'])
print(response_data['title'])
print(response_data['cuisine'])
# Out:
# {'vegetarian': False,
#  'vegan': False,
#  'glutenFree': True,
#  'dairyFree': True,
#  'veryHealthy': False,
#  'cheap': False,
#  'veryPopular': False,
#  'sustainable': False,
#  'weightWatcherSmartPoints': 13,
#  'gaps': 'no',
#  'lowFodmap': False,
#  'ketogenic': False,
#  'whole30': False,
#  'sourceUrl': 'http://www.dinner-mom.com/thai-beef-shaved-broccoli-stalk-ribbons/',
#  'spoonacularSourceUrl': 'https://spoonacular.com/thai-beef-and-shaved-broccoli-stalk-ribbons-611942',
#  'aggregateLikes': 73,
#  'spoonacularScore': 86.0,
#  'healthScore': 24.0,
#  'creditText': 'Dinner Mom',
#  'sourceName': 'Dinner Mom',
#  'pricePerServing': 216.49,
#  'id': 611942,
#  'title': 'Thai Beef and Shaved Broccoli Stalk Ribbons',
#  'readyInMinutes': 45,
#  'servings': 4,
#  'image': 'https://spoonacular.com/recipeImages/611942-312x231.jpg',
#  'imageType': 'jpg',
#  'cuisines': ['asian', 'thai'],
#  'dishTypes': ['lunch', 'main course', 'main dish', 'dinner'],
# ...

# %%
response_data = response.json()['results'][0]
instructions = response_data['analyzedInstructions']
steps = instructions[0]['steps']
lsteps = len(steps)
for i in range(0,lsteps):
    print(steps[i]['step'])
# Out:
# To prepare broccoli ribbons, cut florets from stalks so that you end up with a log shaped stalk.
# Cut log in half (and then cut the halves in half.) See picture in post.Lay cut logs on a cutting board with the smooth side up and use a vegetable peeler to make "ribbons" stopping before you get to the tough outer layer.
# Combine soy sauce (or coconut aminos,) canola oil, coriander and brown sugar in a small bowl and set aside.
# Heat sesame oil in skillet over medium-high heat.
# Add beef to a large skillet and cook for about 3 minutes or until browned and just cooked through.
# Add broccoli stalk ribbons and sauce to skillet, stir to coat beef with sauce.Cook over medium high heat for about 2 minutes more.Top with cilantro.

# %%
for i in response_data:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-fa9e94c637c0> in <module>()
#       1 for i in results_dict:
# ----> 2     response.json()[i]['id']
#
# TypeError: unhashable type: 'dict'

# %%
# @app.route("/recipes/<ingredients>/<cuisine>")
# def recipes_dict(ingredients, cuisine):
#     recipes = pd.read_csv("SELECT cuisine,link FROM recipes_data",engine)
