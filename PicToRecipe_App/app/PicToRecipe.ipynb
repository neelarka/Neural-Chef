# %%
#import required libraries 

from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras import backend as k 
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
import os

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#go to working directory
cd "/content/drive/My Drive/ColabNotebooks/PicToRecipe"
# Out:
# /content/drive/My Drive/ColabNotebooks/PicToRecipe

# %%
#define the veriables
img_width, img_height = 224, 224
train_data_dir = "DataSet/Training_set"
validation_data_dir = "DataSet/Test_set"

# %%
path, data_dir_list, files = next(os.walk(train_data_dir))
data_dir_list
# Out:
# ['Red Tomato',
#  'Broccoli',
#  'Spring Onion',
#  'Mushroom',
#  'Potato',
#  'Carrot',
#  'Corn',
#  'Spinach',
#  'Eggplant',
#  'Onion',
#  'Coliflower',
#  'Green Tomato',
#  'Brussels Sprouts',
#  'Green Beans',
#  'Avocado',
#  'Cabbage',
#  'cucumber',
#  'beet',
#  'sweetpotato',
#  'Okra',
#  'peas',
#  'Pumpkin']

# %%
#Calculate Train samples
train_samples = 0

path, dirs, files = next(os.walk(train_data_dir))
nb_classsifires = len(dirs)
print(nb_classsifires)
for d in dirs:
    path, nub_classifires, files = next(os.walk(train_data_dir + "/" + d))
    train_samples = train_samples+len(files)
    
print(train_samples )
# Out:
# 22
# 1030

# %%
test_samples = 0

path, dirs, files = next(os.walk(validation_data_dir))
for d in dirs:
    path, nub_classifires, files = next(os.walk(validation_data_dir + "/" + d))
    test_samples = test_samples+len(files)
    
print(test_samples)
# Out:
# 276

# %%
batch_size = 10
epochs = 50

# %%
#VGG19 model, with weights pre-trained on ImageNet.
model = applications.VGG19(weights = "imagenet", include_top=False, input_shape = (img_width, img_height, 3))
#model = applications.VGG19(weights = "imagenet", include_top=True, classes=1000, input_shape = None)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 3s 0us/step

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Freeze the layers which you don't want to train. Here I am freezing the first 5 layers.
for layer in model.layers[:5]:
    layer.trainable = False

# %%
#from keras.preprocessing.image import img_to_array

# %%
#x = model.get_layer('fc2').output
#x = Dense(128, activation="relu")(x)
#x = Dropout(0.5)(x)
#x = Dense(128, activation="relu")(x)
#x = Dropout(0.2)(x)
#x = Dense(128, activation="relu")(x)
#predictions = Dense(nb_classsifires, activation="softmax")(x)

# %%
x = model.output
x = Flatten()(x) 
x = Dense(128, activation="relu")(x) 
x = Dropout(0.5)(x) 
x = Dense(128, activation="relu")(x) 
x = Dropout(0.2)(x) 
x = Dense(128, activation="relu")(x) 
predictions = Dense(nb_classsifires, activation="softmax")(x)

# %%
# creating the final model 
model_final = Model(inputs = model.input, outputs = predictions)

# %%
# compile the model 
model_final.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(lr=0.0001, momentum=0.9), metrics=["accuracy"])

# %%
# Initiate the train and test generators with data Augumentation 
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   horizontal_flip = True,
                                   fill_mode = "nearest",
                                   zoom_range = 0.3,
                                   width_shift_range = 0.3,
                                   height_shift_range=0.3,
                                   rotation_range=30)

# %%
test_datagen = ImageDataGenerator(rescale = 1./255,
                                  horizontal_flip = True,
                                  fill_mode = "nearest",
                                  zoom_range = 0.3,
                                  width_shift_range = 0.3,
                                  height_shift_range=0.3,
                                  rotation_range=30)

# %%
train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                    target_size = (img_height, img_width),
                                                    batch_size = batch_size, 
                                                    class_mode = "categorical")
# Out:
# Found 1027 images belonging to 22 classes.

# %%
validation_generator = test_datagen.flow_from_directory(validation_data_dir,
                                                        target_size = (img_height, img_width),
                                                        class_mode = "categorical")
# Out:
# Found 275 images belonging to 22 classes.

# %%
train_generator.class_indices
# Out:
# {'Avocado': 0,
#  'Broccoli': 1,
#  'Brussels Sprouts': 2,
#  'Cabbage': 3,
#  'Carrot': 4,
#  'Coliflower': 5,
#  'Corn': 6,
#  'Eggplant': 7,
#  'Green Beans': 8,
#  'Green Tomato': 9,
#  'Mushroom': 10,
#  'Okra': 11,
#  'Onion': 12,
#  'Potato': 13,
#  'Pumpkin': 14,
#  'Red Tomato': 15,
#  'Spinach': 16,
#  'Spring Onion': 17,
#  'beet': 18,
#  'cucumber': 19,
#  'peas': 20,
#  'sweetpotato': 21}

# %%
import pandas as pd
d = train_generator.class_indices

# %%
d.items()
# Out:
# dict_items([('Avocado', 0), ('Broccoli', 1), ('Brussels Sprouts', 2), ('Cabbage', 3), ('Carrot', 4), ('Coliflower', 5), ('Corn', 6), ('Eggplant', 7), ('Green Beans', 8), ('Green Tomato', 9), ('Mushroom', 10), ('Okra', 11), ('Onion', 12), ('Potato', 13), ('Pumpkin', 14), ('Red Tomato', 15), ('Spinach', 16), ('Spring Onion', 17), ('beet', 18), ('cucumber', 19), ('peas', 20), ('sweetpotato', 21)])

# %%
labels = pd.DataFrame(list(d.items()), columns=['Label', 'Index'])

# %%
labels
# Out:
#                Label  Index
# 0            Avocado      0
# 1           Broccoli      1
# 2   Brussels Sprouts      2
# 3            Cabbage      3
# 4             Carrot      4
# 5         Coliflower      5
# 6               Corn      6
# 7           Eggplant      7
# 8        Green Beans      8
# 9       Green Tomato      9
# 10          Mushroom     10
# 11              Okra     11
# 12             Onion     12
# 13            Potato     13
# 14           Pumpkin     14
# 15        Red Tomato     15
# 16           Spinach     16
# 17      Spring Onion     17
# 18              beet     18
# 19          cucumber     19
# 20              peas     20
# 21       sweetpotato     21

# %%
labels.to_csv("labels.csv", index=False)

# %%
# Save the model according to the conditions  
checkpoint = ModelCheckpoint("vgg19_pictoreceipe_1.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=10, verbose=1, mode='auto')

# %%
# Train the model 
model_final.fit_generator(train_generator,
                          steps_per_epoch = train_samples/4,
                          epochs = epochs,
                          validation_data = validation_generator,
                          validation_steps = test_samples/2,
                          callbacks = [checkpoint, early])
# Out:
# Epoch 1/50
# 258/257 [==============================] - 406s 2s/step - loss: 3.1119 - acc: 0.0488 - val_loss: 3.0855 - val_acc: 0.0348
#
# Epoch 00001: val_acc improved from -inf to 0.03483, saving model to vgg19_pictoreceipe_1.h5
# Epoch 2/50
# 258/257 [==============================] - 212s 820ms/step - loss: 3.0689 - acc: 0.0599 - val_loss: 3.0818 - val_acc: 0.0407
#
# Epoch 00002: val_acc improved from 0.03483 to 0.04075, saving model to vgg19_pictoreceipe_1.h5
# Epoch 3/50
# 258/257 [==============================] - 213s 826ms/step - loss: 3.0556 - acc: 0.0699 - val_loss: 3.0582 - val_acc: 0.0447
#
# Epoch 00003: val_acc improved from 0.04075 to 0.04468, saving model to vgg19_pictoreceipe_1.h5
# Epoch 4/50
# 258/257 [==============================] - 212s 821ms/step - loss: 3.0066 - acc: 0.0772 - val_loss: 3.0439 - val_acc: 0.0498
#
# Epoch 00004: val_acc improved from 0.04468 to 0.04975, saving model to vgg19_pictoreceipe_1.h5
# Epoch 5/50
# 258/257 [==============================] - 211s 818ms/step - loss: 2.9381 - acc: 0.1184 - val_loss: 2.9348 - val_acc: 0.1087
#
# Epoch 00005: val_acc improved from 0.04975 to 0.10874, saving model to vgg19_pictoreceipe_1.h5
# Epoch 6/50
# 258/257 [==============================] - 213s 825ms/step - loss: 2.8345 - acc: 0.1452 - val_loss: 2.8178 - val_acc: 0.1295
#
# Epoch 00006: val_acc improved from 0.10874 to 0.12952, saving model to vgg19_pictoreceipe_1.h5
# Epoch 7/50
# 258/257 [==============================] - 212s 820ms/step - loss: 2.6986 - acc: 0.1825 - val_loss: 2.6172 - val_acc: 0.1864
#
# Epoch 00007: val_acc improved from 0.12952 to 0.18645, saving model to vgg19_pictoreceipe_1.h5
# Epoch 8/50
# 258/257 [==============================] - 214s 829ms/step - loss: 2.4813 - acc: 0.2569 - val_loss: 2.3136 - val_acc: 0.3374
#
# Epoch 00008: val_acc improved from 0.18645 to 0.33736, saving model to vgg19_pictoreceipe_1.h5
# Epoch 9/50
# 258/257 [==============================] - 213s 825ms/step - loss: 2.2699 - acc: 0.3078 - val_loss: 2.0554 - val_acc: 0.3950
#
# Epoch 00009: val_acc improved from 0.33736 to 0.39496, saving model to vgg19_pictoreceipe_1.h5
# Epoch 10/50
# 258/257 [==============================] - 211s 818ms/step - loss: 2.0843 - acc: 0.3664 - val_loss: 1.9727 - val_acc: 0.3947
#
# Epoch 00010: val_acc did not improve from 0.39496
# Epoch 11/50
# 258/257 [==============================] - 212s 821ms/step - loss: 1.8211 - acc: 0.4429 - val_loss: 1.6323 - val_acc: 0.5188
#
# Epoch 00011: val_acc improved from 0.39496 to 0.51883, saving model to vgg19_pictoreceipe_1.h5
# Epoch 12/50
# 258/257 [==============================] - 211s 818ms/step - loss: 1.6684 - acc: 0.4853 - val_loss: 1.4169 - val_acc: 0.5525
#
# Epoch 00012: val_acc improved from 0.51883 to 0.55252, saving model to vgg19_pictoreceipe_1.h5
# Epoch 13/50
# 258/257 [==============================] - 214s 831ms/step - loss: 1.4697 - acc: 0.5453 - val_loss: 1.3121 - val_acc: 0.6271
#
# Epoch 00013: val_acc improved from 0.55252 to 0.62710, saving model to vgg19_pictoreceipe_1.h5
# Epoch 14/50
# 258/257 [==============================] - 213s 825ms/step - loss: 1.3970 - acc: 0.5745 - val_loss: 1.2610 - val_acc: 0.6570
#
# Epoch 00014: val_acc improved from 0.62710 to 0.65695, saving model to vgg19_pictoreceipe_1.h5
# Epoch 15/50
# 258/257 [==============================] - 212s 823ms/step - loss: 1.1933 - acc: 0.6306 - val_loss: 1.0850 - val_acc: 0.6751
#
# Epoch 00015: val_acc improved from 0.65695 to 0.67514, saving model to vgg19_pictoreceipe_1.h5
# Epoch 16/50
# 258/257 [==============================] - 214s 830ms/step - loss: 1.0554 - acc: 0.6752 - val_loss: 0.9822 - val_acc: 0.7036
#
# Epoch 00016: val_acc improved from 0.67514 to 0.70362, saving model to vgg19_pictoreceipe_1.h5
# Epoch 17/50
# 258/257 [==============================] - 212s 820ms/step - loss: 1.0432 - acc: 0.6753 - val_loss: 0.8851 - val_acc: 0.7467
#
# Epoch 00017: val_acc improved from 0.70362 to 0.74674, saving model to vgg19_pictoreceipe_1.h5
# Epoch 18/50
# 258/257 [==============================] - 213s 826ms/step - loss: 0.8689 - acc: 0.7254 - val_loss: 0.9174 - val_acc: 0.7110
#
# Epoch 00018: val_acc did not improve from 0.74674
# Epoch 19/50
# 258/257 [==============================] - 212s 821ms/step - loss: 0.8264 - acc: 0.7462 - val_loss: 0.8900 - val_acc: 0.7240
#
# Epoch 00019: val_acc did not improve from 0.74674
# Epoch 20/50
# 258/257 [==============================] - 213s 827ms/step - loss: 0.7856 - acc: 0.7589 - val_loss: 0.8521 - val_acc: 0.7520
#
# Epoch 00020: val_acc improved from 0.74674 to 0.75195, saving model to vgg19_pictoreceipe_1.h5
# Epoch 21/50
# 258/257 [==============================] - 213s 824ms/step - loss: 0.6848 - acc: 0.7873 - val_loss: 0.8435 - val_acc: 0.7538
#
# Epoch 00021: val_acc improved from 0.75195 to 0.75380, saving model to vgg19_pictoreceipe_1.h5
# Epoch 22/50
# 258/257 [==============================] - 212s 823ms/step - loss: 0.6699 - acc: 0.8037 - val_loss: 0.7063 - val_acc: 0.7908
#
# Epoch 00022: val_acc improved from 0.75380 to 0.79081, saving model to vgg19_pictoreceipe_1.h5
# Epoch 23/50
# 258/257 [==============================] - 213s 825ms/step - loss: 0.5852 - acc: 0.8262 - val_loss: 0.5762 - val_acc: 0.8353
#
# Epoch 00023: val_acc improved from 0.79081 to 0.83535, saving model to vgg19_pictoreceipe_1.h5
# Epoch 24/50
# 258/257 [==============================] - 214s 829ms/step - loss: 0.5355 - acc: 0.8417 - val_loss: 0.6629 - val_acc: 0.8163
#
# Epoch 00024: val_acc did not improve from 0.83535
# Epoch 25/50
# 258/257 [==============================] - 209s 810ms/step - loss: 0.4879 - acc: 0.8607 - val_loss: 0.6871 - val_acc: 0.8057
#
# Epoch 00025: val_acc did not improve from 0.83535
# Epoch 26/50
# 258/257 [==============================] - 211s 817ms/step - loss: 0.4752 - acc: 0.8571 - val_loss: 0.7036 - val_acc: 0.7984
#
# Epoch 00026: val_acc did not improve from 0.83535
# Epoch 27/50
# 258/257 [==============================] - 210s 815ms/step - loss: 0.4332 - acc: 0.8669 - val_loss: 0.4958 - val_acc: 0.8605
#
# Epoch 00027: val_acc improved from 0.83535 to 0.86050, saving model to vgg19_pictoreceipe_1.h5
# Epoch 28/50
# 258/257 [==============================] - 211s 816ms/step - loss: 0.4101 - acc: 0.8745 - val_loss: 0.9070 - val_acc: 0.7868
#
# Epoch 00028: val_acc did not improve from 0.86050
# Epoch 29/50
# 258/257 [==============================] - 212s 823ms/step - loss: 0.4444 - acc: 0.8692 - val_loss: 0.6234 - val_acc: 0.8313
#
# Epoch 00029: val_acc did not improve from 0.86050
# Epoch 30/50
# 258/257 [==============================] - 213s 824ms/step - loss: 0.3504 - acc: 0.8977 - val_loss: 0.8496 - val_acc: 0.7852
#
# Epoch 00030: val_acc did not improve from 0.86050
# Epoch 31/50
# 258/257 [==============================] - 212s 823ms/step - loss: 0.3532 - acc: 0.8992 - val_loss: 0.5448 - val_acc: 0.8465
#
# Epoch 00031: val_acc did not improve from 0.86050
# Epoch 32/50
# 258/257 [==============================] - 213s 826ms/step - loss: 0.3088 - acc: 0.9090 - val_loss: 0.7459 - val_acc: 0.8140
#
# Epoch 00032: val_acc did not improve from 0.86050
# Epoch 33/50
# 258/257 [==============================] - 211s 817ms/step - loss: 0.3163 - acc: 0.9103 - val_loss: 0.7793 - val_acc: 0.7887
#
# Epoch 00033: val_acc did not improve from 0.86050
# Epoch 34/50
# 258/257 [==============================] - 211s 820ms/step - loss: 0.2761 - acc: 0.9264 - val_loss: 0.7231 - val_acc: 0.8119
#
# Epoch 00034: val_acc did not improve from 0.86050
# Epoch 35/50
# 258/257 [==============================] - 213s 824ms/step - loss: 0.2858 - acc: 0.9172 - val_loss: 0.6626 - val_acc: 0.8218
#
# Epoch 00035: val_acc did not improve from 0.86050
# Epoch 36/50
# 258/257 [==============================] - 213s 825ms/step - loss: 0.3077 - acc: 0.9130 - val_loss: 0.7048 - val_acc: 0.8379
#
# Epoch 00036: val_acc did not improve from 0.86050
# Epoch 37/50
# 258/257 [==============================] - 212s 822ms/step - loss: 0.2000 - acc: 0.9401 - val_loss: 0.6973 - val_acc: 0.8294
#
# Epoch 00037: val_acc did not improve from 0.86050
# Epoch 00037: early stopping
